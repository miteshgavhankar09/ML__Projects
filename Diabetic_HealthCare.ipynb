# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\Data_Science\CapStone\Data-Science-Capstone-Projects-master\Project_2\HealthcareDiabetes\Health_care_Diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Documents\\My_Notebooks'

# %%
os.listdir(os.getcwd())
# Out:
# ['.condarc',
#  '.ipynb_checkpoints',
#  'C10.1_ML_PCa_LdA_VB.ipynb',
#  'C10_ML_Hier_Agglo.ipynb',
#  'C10_Pandas_overview...ipynb',
#  'C11_VB_Chi-Square Test.ipynb',
#  'C7_VB_Matplotlib.ipynb',
#  'C8_ML_CrossValidation_XGBoost.ipynb',
#  'C9_DS_Webscraping.ipynb',
#  'C9_ML_Partitional_Clustering_Techniques.ipynb',
#  'Class 5 NumPy VB.ipynb',
#  'Cubic_Function.png',
#  'Data_Pre.ipynb',
#  'Data_Preprocessing.ipynb',
#  'Decision_Tree _KNN_Algo.ipynb',
#  'Diabetic_HealthCare.ipynb',
#  'Ensemble_Demo_Full.ipynb',
#  'health care diabetes new.csv',
#  'Health_care_Diabetes.csv',
#  'Income_Qualification.ipynb',
#  'Item_based_CF_Recommender_System.ipynb',
#  'Linear_Regression.ipynb',
#  'LogReg_Demo.ipynb',
#  'movie_ratings.csv',
#  'movie_ratings2',
#  'movie_ratings_without_row_label.csv',
#  'mtcars.ipynb',
#  'mtcars2.ipynb',
#  'ROC.png']

# %% [markdown]
# # Week No. 1,Task No.1

# %% [markdown]
# **Decriptive Analysis**

# %% [markdown]
# **1. Perform descriptive analysis. Understand the variables and their corresponding values.
# On the columns below, a value of zero does not make sense and thus indicates missing
# value**
#
# • Glucose
#
# • BloodPressure
#
# • SkinThickness
#
# • Insulin
#
# • BMI

# %% [markdown]
# **It is a summary statistic that quantitatively describes or summarizes features from a collection of information.**

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['Pregnancies'].max()
# Out:
# 17

# %%
df['Pregnancies'].min()
# Out:
# 0

# %%
df['Glucose'].max()
# Out:
# 199

# %%
df['Glucose'].min()
# Out:
# 0

# %%
df.describe(include = "all")
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# **Here,We Could infer that there is far difference in mean & median(50%) values of "Insulin" & "Age" columns in this dataset.**

# %%
df.dtypes # type of features  & target variable in dataset..
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.info() # here,we can get glimpse of dataset columns..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().sum() # To get the how many null values are there in the each columns..
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# **Correlation** explains how one or more variables are related to each other.

# %%
df.corr() # All the diagonal values are 1.
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
sns.heatmap(df.isnull(),yticklabels = False,cbar=False,cmap = 'Accent')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
df.boxplot();

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
for i in ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']:
    print(i)
    print(df[i].value_counts(normalize=True)[0],"\n\n")
# Out:
# Glucose
# 0.006510416666666667
#
#
# BloodPressure
# 0.045572916666666664
#
#
# SkinThickness
# 0.2955729166666667
#
#
# Insulin
# 0.4869791666666667
#
#
# BMI
# 0.014322916666666666

# %%
df[df["Insulin"]!=0]["Insulin"].median() # checking the median value of "Insulin" column
# Out:
# 125.0

# %%
df[df["Age"]!=0]["Age"].median() # checking the median value of "Age" column
# Out:
# 29.0

# %% [markdown]
# **Replacing zeros with Median values**

# %%
for i in ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']:
    print(i)
    
    # print(df[df[i]!=0][i].median(),"\n\n")
    
    median_value = df[df[i]!=0][i].median() # df[df[i]!=0][i]-->Finding non-zero data points..
    
    print(median_value)
    
    df[i].replace(0,median_value,inplace=True)
# Out:
# Glucose
# 117.0
# BloodPressure
# 72.0
# SkinThickness
# 29.0
# Insulin
# 125.0
# BMI
# 32.3

# %%
df[df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI']]==0].count() 

# checking whether change has impacted data or not here in this case it is impacted & changes has been made..
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Task No.2

# %% [markdown]
# **2. Visually explore these variables using histograms. Treat the missing values
# accordingly.**

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# **Creating Histogram..**

# %%
x =  ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI']

color = ['b','g','r','c','y']

for (i,j) in zip(x,color):
    print(i)
    print(j)
    plt.hist(df[i],color=j,bins =10)
    plt.show()
# Out:
# Glucose
# b
# BloodPressure
# g
# SkinThickness
# r
# Insulin
# c
# BMI
# y

# %% [markdown]
# # Task No. 3

# %% [markdown]
# **3. There are integer and float data type variables in this dataset. Create a count
# (frequency) plot describing the data types and the count of variables.**

# %%
sns.countplot(df['Outcome']);
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(y=df['Pregnancies']);

# %%
plt.figure(figsize=(18,18))
sns.countplot(y=df['Glucose']);

# %%
sns.countplot(y=df['BloodPressure']);
plt.figure(figsize=(18,18))

# %%
sns.countplot(y=df['SkinThickness']);

# %%
plt.figure(figsize=(18,18))
sns.countplot(y=df['Insulin'],orient = "h");

# %% [markdown]
# **Count of Variables**

# %%
df.dtypes.value_counts() # Count of variables
# Out:
# int64      7
# float64    2
# dtype: int64

# %% [markdown]
# # Week No. 2,Task No.1

# %% [markdown]
# **Data Exploration**
#
# **1. Check the balance of the data by plotting the count of outcomes by their value.
# Describe your findings and plan future course of action.**

# %%
# Age with Pregnancies and Outcome
sns.pointplot(x="Pregnancies",y='Age', hue="Outcome" ,data=df)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Age'>

# %%
# Glucose with Outcome as hue = "Outcome"
sns.histplot(x='Glucose', data=df, kde=True, hue="Outcome");

# %%
# SkinThickness with Insulin
sns.jointplot(x='Insulin',y='SkinThickness',hue='Outcome',data=df);

# %%
df.Outcome.value_counts(normalize=True)*100
# Out:
# 0    65.104167
# 1    34.895833
# Name: Outcome, dtype: float64

# %% [markdown]
# **2. Create scatter charts between the pair of variables to understand the relationships.
# Describe your findings.**

# %%
plt.figure(figsize=(5,5))

sns.pairplot(df,hue='Outcome')

plt.show()

# %%
sns.distplot(df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# **3. Perform correlation analysis. Visually explore it using a heat map.**

# %%
plt.figure(figsize=(10,6))

sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# # Week No. 3,Task No.1

# %% [markdown]
# # Data Modeling

# %% [markdown]
# **1. Devise strategies for model building. It is important to decide the right validation
# framework. Express your thought process.**

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop("Outcome",axis=1)
y = df["Outcome"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=5,test_size =25,stratify =y)

# %%
final_output = pd.DataFrame()
final_output['Actual Output'] = y_test

# %%
df["Outcome"].value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=5,test_size =25,stratify =y)

# %%
x_train.shape
# Out:
# (743, 8)

# %%
x_test.shape
# Out:
# (25, 8)

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.651413
# 1    0.348587
# Name: Outcome, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.64
# 1    0.36
# Name: Outcome, dtype: float64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model =KNeighborsClassifier(3)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scalled_train_x = scaler.fit_transform(x_train)

# %%
scalled_test_x = scaler.fit_transform(x_test)

# %%
# scaler.fit(train_x)
# scalled_train_x = scaler.fit_transform(train_x)
scalled_train_x
# Out:
# array([[0.23529412, 0.71428571, 0.3877551 , ..., 0.29856851, 0.06789069,
#         0.03333333],
#        [0.        , 0.66233766, 0.59183673, ..., 0.45603272, 0.72715628,
#         0.38333333],
#        [0.64705882, 0.43506494, 0.6122449 , ..., 0.58486708, 0.3616567 ,
#         0.4       ],
#        ...,
#        [0.        , 1.        , 0.42857143, ..., 0.47239264, 0.18104184,
#         0.11666667],
#        [0.58823529, 0.15584416, 0.83673469, ..., 0.35378323, 0.08838599,
#         0.43333333],
#        [0.23529412, 0.74025974, 0.55102041, ..., 0.3006135 , 0.30956447,
#         0.16666667]])

# %%
scalled_test_x = scaler.fit_transform(x_test)
scalled_test_x
# Out:
# array([[6.00000000e-01, 4.26573427e-01, 4.76190476e-01, 7.94117647e-01,
#         2.16101695e-01, 7.08154506e-01, 3.68156073e-01, 4.44444444e-01],
#        [3.00000000e-01, 3.84615385e-01, 1.90476190e-01, 7.35294118e-01,
#         2.16101695e-01, 3.26180258e-01, 2.61170548e-01, 2.00000000e-01],
#        [1.00000000e-01, 1.00000000e+00, 6.66666667e-01, 8.52941176e-01,
#         2.16101695e-01, 8.75536481e-01, 7.87916929e-01, 2.22222222e-02],
#        [2.00000000e-01, 6.15384615e-01, 2.38095238e-01, 5.58823529e-01,
#         2.37288136e-01, 3.90557940e-01, 1.76211454e-01, 8.88888889e-02],
#        [0.00000000e+00, 4.33566434e-01, 8.57142857e-01, 9.70588235e-01,
#         4.38559322e-01, 1.00000000e+00, 2.57394588e-01, 2.22222222e-01],
#        [1.00000000e-01, 4.19580420e-01, 5.23809524e-01, 4.11764706e-01,
#         2.16101695e-01, 2.10300429e-01, 3.90182505e-02, 0.00000000e+00],
#        [9.00000000e-01, 6.22377622e-01, 9.52380952e-01, 5.88235294e-01,
#         3.00847458e-01, 3.34763948e-01, 3.95846444e-01, 7.11111111e-01],
#        [8.00000000e-01, 8.74125874e-01, 4.76190476e-01, 6.47058824e-01,
#         1.00000000e+00, 3.26180258e-01, 2.97671492e-01, 8.66666667e-01],
#        [0.00000000e+00, 5.66433566e-01, 4.76190476e-01, 0.00000000e+00,
#         2.64830508e-01, 9.87124464e-02, 6.29326621e-04, 0.00000000e+00],
#        [0.00000000e+00, 5.31468531e-01, 7.14285714e-01, 4.41176471e-01,
#         2.16101695e-01, 4.24892704e-01, 1.57960982e-01, 0.00000000e+00],
#        [0.00000000e+00, 4.33566434e-01, 3.80952381e-01, 2.64705882e-01,
#         1.39830508e-01, 4.20600858e-01, 1.00000000e+00, 0.00000000e+00],
#        [1.00000000e-01, 2.72727273e-01, 6.19047619e-01, 2.05882353e-01,
#         1.05932203e-01, 1.45922747e-01, 3.34172435e-01, 3.33333333e-01],
#        [1.00000000e-01, 1.60839161e-01, 2.85714286e-01, 8.23529412e-01,
#         5.29661017e-02, 9.01287554e-01, 3.37319069e-01, 4.44444444e-02],
#        [1.00000000e-01, 4.26573427e-01, 6.19047619e-01, 1.76470588e-01,
#         0.00000000e+00, 2.23175966e-01, 9.88042794e-02, 0.00000000e+00],
#        [8.00000000e-01, 3.00699301e-01, 8.57142857e-01, 4.41176471e-01,
#         2.16101695e-01, 5.53648069e-01, 1.54814349e-01, 6.44444444e-01],
#        [2.00000000e-01, 3.07692308e-01, 4.28571429e-01, 1.76470588e-01,
#         1.41949153e-01, 4.46351931e-01, 4.56261800e-01, 1.55555556e-01],
#        [0.00000000e+00, 4.26573427e-01, 5.71428571e-01, 4.41176471e-01,
#         2.16101695e-01, 4.84978541e-01, 4.97168030e-01, 5.11111111e-01],
#        [9.00000000e-01, 2.30769231e-01, 3.33333333e-01, 4.41176471e-01,
#         2.16101695e-01, 0.00000000e+00, 0.00000000e+00, 2.66666667e-01],
#        [1.00000000e+00, 6.43356643e-01, 8.57142857e-01, 1.00000000e+00,
#         4.53389831e-01, 6.48068670e-01, 5.40591567e-01, 6.66666667e-01],
#        [2.00000000e-01, 7.13286713e-01, 1.00000000e+00, 4.41176471e-01,
#         2.16101695e-01, 3.90557940e-01, 4.17243549e-01, 1.00000000e+00],
#        [5.00000000e-01, 1.53846154e-01, 0.00000000e+00, 4.41176471e-01,
#         2.16101695e-01, 4.80686695e-01, 3.22215230e-01, 8.88888889e-02],
#        [6.00000000e-01, 3.42657343e-01, 7.61904762e-01, 4.11764706e-01,
#         2.16101695e-01, 4.29184549e-01, 4.63184393e-01, 1.11111111e-01],
#        [2.00000000e-01, 0.00000000e+00, 1.90476190e-01, 4.11764706e-01,
#         4.66101695e-02, 7.29613734e-02, 1.19572058e-01, 2.22222222e-02],
#        [1.00000000e-01, 3.70629371e-01, 2.38095238e-01, 1.17647059e-01,
#         1.97033898e-01, 2.57510730e-01, 4.84581498e-02, 2.22222222e-02],
#        [2.00000000e-01, 4.61538462e-01, 9.52380952e-02, 8.52941176e-01,
#         2.86016949e-01, 5.87982833e-01, 4.24166142e-01, 1.55555556e-01]])

# %%
model.fit(scalled_train_x,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model.score(scalled_train_x,y_train)
# Out:
# 0.8465679676985195

# %%
model.score(scalled_test_x,y_test)
# Out:
# 0.76

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
y_pred= model.predict(scalled_test_x)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        16
#            1       0.64      0.78      0.70         9
#
#     accuracy                           0.76        25
#    macro avg       0.75      0.76      0.75        25
# weighted avg       0.78      0.76      0.76        25

# %%
from sklearn.metrics import accuracy_score

print("The accuracy score of the model on test data is :")
print(accuracy_score(y_test,y_pred)) # --> Actual values & Predicted value
# Out:
# The accuracy score of the model on test data is :
# 0.76

# %%
final_output['KNN'] = y_pred
final_output.head()
# Out:
#      Actual Output  KNN
# 502              1    1
# 256              0    1
# 661              1    1
# 301              1    1
# 16               1    1

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[12  4]
#  [ 2  7]]

# %% [markdown]
# Compairing Results with Logistic Regression.

# %%
x = df.drop("Outcome" ,axis =1)
y = df["Outcome"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x , y ,test_size = 25, random_state =5,stratify =y)

# %%
print("Shape of x_train is : ", x_train.shape)
print("Shape of x_test is : ", x_test.shape)
print("Shape of y_train is : ", y_train.shape)
print("Shape of y_test is : ", y_test.shape)
# Out:
# Shape of x_train is :  (743, 8)
# Shape of x_test is :  (25, 8)
# Shape of y_train is :  (743,)
# Shape of y_test is :  (25,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg_model = LogisticRegression(solver = "newton-cg") 
# --> When your data is continuous numerical 'newton-cg' is more appropriate than 'lbfgs'.
# --> newton-cg -- within max_iter=100 there is still convergence so we put newton-cg to increase interations.

# %%
logreg_model.fit(x_train,y_train)
# Out:
# LogisticRegression(solver='newton-cg')

# %%
y_pred_test = logreg_model.predict(x_test )

# %%
from sklearn.metrics import accuracy_score

print("The accuracy score of the model on test data is :")
print(accuracy_score(y_test,y_pred_test)) # --> Actual values & Predicted value
# Out:
# The accuracy score of the model on test data is :
# 0.88

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# # Classification Report of KNN Algorithm..

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        16
#            1       0.64      0.78      0.70         9
#
#     accuracy                           0.76        25
#    macro avg       0.75      0.76      0.75        25
# weighted avg       0.78      0.76      0.76        25

# %% [markdown]
# # Classification Report of Logistic Regression Model..

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91        16
#            1       1.00      0.67      0.80         9
#
#     accuracy                           0.88        25
#    macro avg       0.92      0.83      0.86        25
# weighted avg       0.90      0.88      0.87        25

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test,y_pred_test))
# Out:
# [[16  0]
#  [ 3  6]]

# %%
final_output['Logistic_Regression'] = y_pred_test
final_output.head()
# Out:
#      Actual Output  KNN  Logistic_Regression
# 502              1    1                    1
# 256              0    1                    0
# 661              1    1                    1
# 301              1    1                    0
# 16               1    1                    0

# %% [markdown]
# # Checking Results With Decision Tree Classifier

# %% [markdown]
# **Importing Required libraries**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier() # Instantiating the estimator object

# %% [markdown]
# **Fitting The Model**

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Declaring The Predicted Variable**

# %%
y_predict = dt_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_predict,y_test)

print("The Prediction accuracy score of the Decision Tree model on test data is :", accuracy)
# Out:
# The Prediction accuracy score of the Decision Tree model on test data is : 0.84

# %%
y_predict_train = dt_model.predict(x_train)

accuracy = accuracy_score(y_predict_train,y_train)

print("The Prediction accuracy score of the Decision Tree model on train data is :", accuracy)
# Out:
# The Prediction accuracy score of the Decision Tree model on train data is : 1.0

# %% [markdown]
# # Let's check whether Pruning affects the accuracy of the model..

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model4 = DecisionTreeClassifier(max_depth=3) # Instantiating the estimator object

dt_model4.fit(x_train,y_train)

y_predict4 = dt_model4.predict(x_test)

# %%
accuracy = accuracy_score(y_predict4,y_test)

print("The Prediction accuracy score of the Decision Tree model on test data is :", accuracy)
# Out:
# The Prediction accuracy score of the Decision Tree model on test data is : 0.84

# %%
y_predict_train = dt_model4.predict(x_train)

accuracy = accuracy_score(y_predict_train,y_train)

print("The Prediction accuracy score of the Decision Tree model on train data is :", accuracy)
# Out:
# The Prediction accuracy score of the Decision Tree model on train data is : 0.7725437415881561

# %% [markdown]
# From the above we could infer that pruning does affect the model accuracy..

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# # Classification Report of Decision Tree model.

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        16
#            1       0.78      0.78      0.78         9
#
#     accuracy                           0.84        25
#    macro avg       0.83      0.83      0.83        25
# weighted avg       0.84      0.84      0.84        25

# %% [markdown]
# # Classification Report Of KNN algorithm..

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        16
#            1       0.78      0.78      0.78         9
#
#     accuracy                           0.84        25
#    macro avg       0.83      0.83      0.83        25
# weighted avg       0.84      0.84      0.84        25

# %%
final_output['Decision_Tree'] = y_predict
final_output.head()
# Out:
#      Actual Output  KNN  Logistic_Regression  Decision_Tree
# 502              1    1                    1              0
# 256              0    1                    0              0
# 661              1    1                    1              1
# 301              1    1                    0              1
# 16               1    1                    0              1

# %% [markdown]
# # Let's Try Naive Baye's Classifier - GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb_model = GaussianNB()

# %%
gnb_model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_test_gnb = gnb_model.predict(x_test)

# %%
accuracy = accuracy_score(y_pred_test_gnb,y_test)
print("The Prediction accuracy score of the GaussianNB model on test data is :", accuracy)
# Out:
# The Prediction accuracy score of the GaussianNB model on test data is : 0.88

# %%
y_predict_train = gnb_model.predict(x_train)

accuracy = accuracy_score(y_predict_train,y_train)

print("The Prediction accuracy score of the GaussianNB model on train data is :", accuracy)
# Out:
# The Prediction accuracy score of the GaussianNB model on train data is : 0.7496635262449529

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# # Classification Report of Naive Baye's Classifier

# %%
print(classification_report(y_test,y_pred_test_gnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        16
#            1       0.88      0.78      0.82         9
#
#     accuracy                           0.88        25
#    macro avg       0.88      0.86      0.87        25
# weighted avg       0.88      0.88      0.88        25

# %% [markdown]
# # Classification Report Of KNN

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        16
#            1       0.64      0.78      0.70         9
#
#     accuracy                           0.76        25
#    macro avg       0.75      0.76      0.75        25
# weighted avg       0.78      0.76      0.76        25

# %%
final_output['Naive Baye\'s'] = y_pred
final_output.head()
# Out:
#      Actual Output  KNN  Logistic_Regression  Decision_Tree  Naive Baye's
# 502              1    1                    1              0             1
# 256              0    1                    0              0             1
# 661              1    1                    1              1             1
# 301              1    1                    0              1             1
# 16               1    1                    0              1             1

# %% [markdown]
# # Let's Try XGBClassifier

# %%
from xgboost.sklearn import XGBClassifier

# %%
xgb_clf_model = XGBClassifier(objective = "multi:softmax",num_class =3)

# %%
xgb_clf_model.fit(x_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:30:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softmax' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_class=3, num_parallel_tree=1, objective='multi:softmax',
#               predictor='auto', random_state=0, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=None, subsample=1, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
y_pred_test2 = xgb_clf_model.predict(x_test)

# %%
print("The testing accuracy of the xgb clf model is :")

print(accuracy_score(y_test,y_pred_test2))
# Out:
# The testing accuracy of the xgb clf model is :
# 0.8

# %%
y_predict_train = xgb_clf_model.predict(x_train)

accuracy = accuracy_score(y_predict_train,y_train)

print("The Prediction accuracy score of the XGBClassifier model on train data is :", accuracy)
# Out:
# The Prediction accuracy score of the XGBClassifier model on train data is : 1.0

# %% [markdown]
# **from the above we could infer that model overfits here and need hyperparameter tuning.**

# %% [markdown]
# # Hyperparameter Tuning

# %%
xgb_clf_model = XGBClassifier(objective = "multi:softmax",num_class =3,
                              subsample = 0.8,
                              n_estimators = 200,
                              min_child_weight =1,
                              learning_rate =0.01,
                             reg_alpha=0,
                             reg_lambda= 1)

xgb_clf_model.fit(x_train,y_train)
y_pred_test2 = xgb_clf_model.predict(x_test)

print("The testing accuracy of the xgb clf model is :")

print(accuracy_score(y_test,y_pred_test2))

y_predict_train = xgb_clf_model.predict(x_train)

accuracy = accuracy_score(y_predict_train,y_train)

print("The Prediction accuracy score of the XGBClassifier model on train data is :", accuracy)
# Out:
# [15:30:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softmax' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\HP\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# The testing accuracy of the xgb clf model is :
# 0.92
# The Prediction accuracy score of the XGBClassifier model on train data is : 0.927321668909825

# %%
final_output['XGBoost'] = y_pred_test2
final_output.head()
# Out:
#      Actual Output  KNN  Logistic_Regression  Decision_Tree  Naive Baye's  \
# 502              1    1                    1              0             1
# 256              0    1                    0              0             1
# 661              1    1                    1              1             1
# 301              1    1                    0              1             1
# 16               1    1                    0              1             1
#
#      XGBoost
# 502        1
# 256        0
# 661        1
# 301        1
# 16         1

# %% [markdown]
# **The training & Testing accuracy is same and this is generalised model can be used for prediction as compared to KNN..**

# %% [markdown]
# # Build SVC Model

# %%
from sklearn.svm import SVC

svc_model = SVC()
                            
svc_model.fit(x_train,y_train)

y_pred_test_svc = svc_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

print("The accuracy score of the  SVC model on test data is :")
print(accuracy_score(y_test,y_pred_test_svc)) # --> Actual values & Predicted value
# Out:
# The accuracy score of the  SVC model on test data is :
# 0.84

# %%
y_pred_train = svc_model.predict(x_train)

# %%
print("The accuracy score of the SVC model on train data is :")
print(accuracy_score(y_train,y_pred_train)) # --> Actual values & Predicted value
# Out:
# The accuracy score of the SVC model on train data is :
# 0.765814266487214

# %%
final_output['SVC'] = y_pred_test_svc
final_output.head()
# Out:
#      Actual Output  KNN  Logistic_Regression  Decision_Tree  Naive Baye's  \
# 502              1    1                    1              0             1
# 256              0    1                    0              0             1
# 661              1    1                    1              1             1
# 301              1    1                    0              1             1
# 16               1    1                    0              1             1
#
#      XGBoost  SVC
# 502        1    0
# 256        0    0
# 661        1    1
# 301        1    0
# 16         1    0

# %% [markdown]
# # Project Task: Week 4
#
# **Data Modeling**
#
# **1. Create a classification report by analyzing sensitivity, specificity, AUC (ROC curve),
# etc. Please be descriptive to explain what values of these parameter you have used.**

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, y_pred[:,], pos_label=1) # knn
fpr2, tpr2, thresh2 = roc_curve(y_test, y_pred_test[:,], pos_label=1) # logistic
fpr3, tpr3, thresh3 = roc_curve(y_test, y_pred_test_gnb[:,], pos_label=1) # naive baye's
fpr4, tpr4, thresh4 = roc_curve(y_test, y_pred_test_svc[:,], pos_label=1) # svc
fpr5, tpr5, thresh5 = roc_curve(y_test, y_pred_test2[:,], pos_label=1) # xgb
fpr6, tpr6, thresh6 = roc_curve(y_test, y_predict[:,], pos_label=1) # Decision Tree


# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
plt.style.use('seaborn')

# plot roc curves
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='KNN')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='logistic')
plt.plot(fpr3, tpr3, linestyle='--',color='red', label='Naive Bayes Classifier')
plt.plot(fpr4, tpr4, linestyle='--',color='pink', label='svc')
plt.plot(fpr5, tpr5, linestyle='--',color='cyan', label='xgb')
plt.plot(fpr6, tpr6, linestyle='--',color='magenta', label='Decision tree')


plt.plot(p_fpr, p_tpr, linestyle='--', color='black')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=2000)
plt.show();

# %% [markdown]
# **From the above we could infer that**
#
# **KNN,Decision Tree & Naive Baye's Classifier has same curve**
#
# **&**
#
# **XGBoost having Excellent Curve**
#
# **&**
#
# **svc having worst curve.**

# %% [markdown]
# For Tableau Project we are using file without Null Values or Missing values.

# %%
df.to_csv("Health_care_Diabetes.csv")

# %% [markdown]
# # End Of Notebook
