# %%
import pandas as pd

# %%
income_df = pd.read_csv(r"C:\Users\HP\Desktop\Data_Science\ML\Income_Qualification\train.csv")
income_df.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  SQBhogar_nin  \
# 0     0  ...          100    1849               1        100             0
# 1     0  ...          144    4489               1        144             0
# 2     0  ...          121    8464               1          0             0
# 3     0  ...           81     289              16        121             4
# 4     0  ...          121    1369              16        121             4
#
# ...

# %%
income_df.describe
# Out:
# <bound method NDFrame.describe of                 Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  \
# 0     ID_279628684  190000.0       0      3       0     1       1     0
# 1     ID_f29eb3ddd  135000.0       0      4       0     1       1     1
# 2     ID_68de51c94       NaN       0      8       0     1       1     0
# 3     ID_d671db89c  180000.0       0      5       0     1       1     1
# 4     ID_d56d6f5f5  180000.0       0      5       0     1       1     1
# ...            ...       ...     ...    ...     ...   ...     ...   ...
# 9552  ID_d45ae367d   80000.0       0      6       0     1       1     0
# 9553  ID_c94744e07   80000.0       0      6       0     1       1     0
# 9554  ID_85fc658f8   80000.0       0      6       0     1       1     0
# 9555  ID_ced540c61   80000.0       0      6       0     1       1     0
# 9556  ID_a38c64491   80000.0       0      6       0     1       1     0
#
# ...

# %%
income_df.isnull().sum()
# Out:
# Id                    0
# v2a1               6860
# hacdor                0
# rooms                 0
# hacapo                0
#                    ...
# SQBovercrowding       0
# SQBdependency         0
# SQBmeaned             5
# agesq                 0
# Target                0
# Length: 143, dtype: int64

# %%
income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9557 entries, 0 to 9556
# Columns: 143 entries, Id to Target
# dtypes: float64(8), int64(130), object(5)
# memory usage: 10.4+ MB

# %% [markdown]
# # Checking Type Of Data

# %%
income_df.dtypes
# Out:
# Id                  object
# v2a1               float64
# hacdor               int64
# rooms                int64
# hacapo               int64
#                     ...
# SQBovercrowding    float64
# SQBdependency      float64
# SQBmeaned          float64
# agesq                int64
# Target               int64
# Length: 143, dtype: object

# %% [markdown]
# # Check if there are any biases in your dataset.

# %%
income_df["Target"].value_counts()
# Out:
# 4    5996
# 2    1597
# 3    1209
# 1     755
# Name: Target, dtype: int64

# %%
income_df.shape
# Out:
# (9557, 143)

# %% [markdown]
# # Check if there is a house without a family head.

# %%
income_df[["parentesco1"]].value_counts()
# Out:
# parentesco1
# 0              6584
# 1              2973
# dtype: int64

# %% [markdown]
#  0 reprents no family head
#
#  1 represents family head

# %% [markdown]
# # Count how many null values are existing in columns.

# %%
for i in income_df:
    print(f"Null Values {i} in column is --> {income_df[i].isnull().sum()/income_df.shape[0] * 100}")
# Out:
# Null Values Id in column is --> 0.0
# Null Values v2a1 in column is --> 71.7798472323951
# Null Values hacdor in column is --> 0.0
# Null Values rooms in column is --> 0.0
# Null Values hacapo in column is --> 0.0
# Null Values v14a in column is --> 0.0
# Null Values refrig in column is --> 0.0
# Null Values v18q in column is --> 0.0
# Null Values v18q1 in column is --> 76.82327090091033
# Null Values r4h1 in column is --> 0.0
# Null Values r4h2 in column is --> 0.0
# Null Values r4h3 in column is --> 0.0
# Null Values r4m1 in column is --> 0.0
# Null Values r4m2 in column is --> 0.0
# Null Values r4m3 in column is --> 0.0
# Null Values r4t1 in column is --> 0.0
# Null Values r4t2 in column is --> 0.0
# Null Values r4t3 in column is --> 0.0
# Null Values tamhog in column is --> 0.0
# Null Values tamviv in column is --> 0.0
# Null Values escolari in column is --> 0.0
# Null Values rez_esc in column is --> 82.95490216595167
# Null Values hhsize in column is --> 0.0
# ...

# %%
for i in income_df:
    if (income_df[i].isnull().sum()/income_df.shape[0] * 100) > 50 :
        income_df.drop(i, axis=1, inplace=True)
    elif (income_df[i].isnull().sum()/income_df.shape[0] * 100) > 0 and income_df[i].dtypes == 'float64':
        income_df.fillna(income_df[i].mean(), inplace=True)

# %%
for i in income_df:
    print(f"Null Values {i} in column is --> {income_df[i].isnull().sum()/income_df.shape[0] * 100}")
# Out:
# Null Values Id in column is --> 0.0
# Null Values hacdor in column is --> 0.0
# Null Values rooms in column is --> 0.0
# Null Values hacapo in column is --> 0.0
# Null Values v14a in column is --> 0.0
# Null Values refrig in column is --> 0.0
# Null Values v18q in column is --> 0.0
# Null Values r4h1 in column is --> 0.0
# Null Values r4h2 in column is --> 0.0
# Null Values r4h3 in column is --> 0.0
# Null Values r4m1 in column is --> 0.0
# Null Values r4m2 in column is --> 0.0
# Null Values r4m3 in column is --> 0.0
# Null Values r4t1 in column is --> 0.0
# Null Values r4t2 in column is --> 0.0
# Null Values r4t3 in column is --> 0.0
# Null Values tamhog in column is --> 0.0
# Null Values tamviv in column is --> 0.0
# Null Values escolari in column is --> 0.0
# Null Values hhsize in column is --> 0.0
# Null Values paredblolad in column is --> 0.0
# Null Values paredzocalo in column is --> 0.0
# Null Values paredpreb in column is --> 0.0
# Null Values pareddes in column is --> 0.0
# ...

# %%
for i in income_df:
    if income_df[i].dtypes == 'O':
        print(i,income_df[i])
# Out:
# Id 0       ID_279628684
# 1       ID_f29eb3ddd
# 2       ID_68de51c94
# 3       ID_d671db89c
# 4       ID_d56d6f5f5
#             ...
# 9552    ID_d45ae367d
# 9553    ID_c94744e07
# 9554    ID_85fc658f8
# 9555    ID_ced540c61
# 9556    ID_a38c64491
# Name: Id, Length: 9557, dtype: object
# idhogar 0       21eb7fcc1
# 1       0e5d7a658
# 2       2c7317ea8
# 3       2b58d945f
# 4       2b58d945f
#           ...
# 9552    d6c086aa3
# 9553    d6c086aa3
# 9554    d6c086aa3
# 9555    d6c086aa3
# 9556    d6c086aa3
# Name: idhogar, Length: 9557, dtype: object
# dependency 0        no
# 1         8
# 2         8
# 3       yes
# 4       yes
#        ...
# 9552    .25
# 9553    .25
# 9554    .25
# 9555    .25
# 9556    .25
# Name: dependency, Length: 9557, dtype: object
# edjefe 0       10
# 1       12
# 2       no
# 3       11
# 4       11
#         ..
# 9552     9
# 9553     9
# 9554     9
# 9555     9
# 9556     9
# Name: edjefe, Length: 9557, dtype: object
# edjefa 0       no
# 1       no
# ...
